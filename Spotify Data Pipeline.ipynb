# %%
# !pip install spotipy

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
client_credentials_manager = SpotifyClientCredentials(client_id="#", client_secret="#")

# %%
#creating a spotify object
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
#Getting the playlist ID
playlist_link = "https://open.spotify.com/playlist/37i9dQZEVXbNG2KDcFcKOF"

# %%
playlist_URI = playlist_link.split("/")[-1]

# %%
data = sp.playlist_tracks(playlist_URI)

# %%
import json
with open('data.json', 'w') as f:
    json.dump(data, f)

# %%
data['items']
# Out:
# [{'added_at': '2023-03-03T10:15:38Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5YGY8feqx7naU7z4HrwZM6'},
#       'href': 'https://api.spotify.com/v1/artists/5YGY8feqx7naU7z4HrwZM6',
#       'id': '5YGY8feqx7naU7z4HrwZM6',
#       'name': 'Miley Cyrus',
#       'type': 'artist',
#       'uri': 'spotify:artist:5YGY8feqx7naU7z4HrwZM6'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
# ...

# %%
data['items'][0]['track']['album']['id']
# Out:
# '7I0tjwFtxUwBC1vgyeMAax'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'Flowers'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2023-01-13'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 1

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/7I0tjwFtxUwBC1vgyeMAax'

# %%
album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    album_element = {'album_id':album_id,'name':album_name,'release_date':album_release_date,
                        'total_tracks':album_total_tracks,'url':album_url}
    album_list.append(album_element)

# %%
artist_list = []
for row in data['items']:
    for key, value in row.items():
        if key == "track":
            for artist in value['artists']:
                artist_dict = {'artist_id':artist['id'], 'artist_name':artist['name'], 'external_url': artist['href']}
                artist_list.append(artist_dict)

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id,'song_name':song_name,'duration_ms':song_duration,'url':song_url,
                    'popularity':song_popularity,'song_added':song_added,'album_id':album_id,
                    'artist_id':artist_id
                   }
    song_list.append(song_element)

# %%
album_df = pd.DataFrame.from_dict(album_list)

# %%
album_df.head()
# Out:
#                  album_id                 name release_date  total_tracks  \
# 0  7I0tjwFtxUwBC1vgyeMAax              Flowers   2023-01-13             1
# 1  4kS7bSuU0Jm9LYMosFU2x5   MAÑANA SERÁ BONITO   2023-02-24            17
# 2  6Exo0MYoL3XammoTDeihFy  Die For You (Remix)   2023-02-24             1
# 3  1nrVofqDRs7cpWXJ49qTnP                  SOS   2022-12-08            23
# 4  6cVfHBcp3AdpYY0bBglkLN   Boy's a liar Pt. 2   2023-02-03             2
#
#                                                  url
# 0  https://open.spotify.com/album/7I0tjwFtxUwBC1v...
# 1  https://open.spotify.com/album/4kS7bSuU0Jm9LYM...
# 2  https://open.spotify.com/album/6Exo0MYoL3Xammo...
# 3  https://open.spotify.com/album/1nrVofqDRs7cpWX...
# 4  https://open.spotify.com/album/6cVfHBcp3AdpYY0...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      50 non-null     object
#  1   name          50 non-null     object
#  2   release_date  50 non-null     object
#  3   total_tracks  50 non-null     int64
#  4   url           50 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.1+ KB

# %%
# Dropping the duplicates in our album_df dataframe
album_df = album_df.drop_duplicates(subset=['album_id'])

# %%
artist_df = pd.DataFrame.from_dict(artist_list)

# %%
artist_df
# Out:
#                  artist_id       artist_name  \
# 0   5YGY8feqx7naU7z4HrwZM6       Miley Cyrus
# 1   790FomKkXshlbRYZFtlgla           KAROL G
# 2   0EmeFodog0BfCgMzAIvKQp           Shakira
# 3   1Xyo4u8uXC1ZmMpatF05PJ        The Weeknd
# 4   66CXWjxzNUsdJxJ2JdwvnR     Ariana Grande
# ..                     ...               ...
# 71  3m5qlPf2OkihLz3dRYnkPA  Ovy On The Drums
# 72  66ihevNkSYNzRAl44dx6jJ        Carin Leon
# 73  6XkjpgcEsYab502Vr1bBeW    Grupo Frontera
# 74  2LRoIwlKmHjgvigdNGBHNo              Feid
# 75  6JL8zeS1NmiOftqZTRgdTz    Meghan Trainor
#
#                                          external_url
# 0   https://api.spotify.com/v1/artists/5YGY8feqx7n...
# 1   https://api.spotify.com/v1/artists/790FomKkXsh...
# 2   https://api.spotify.com/v1/artists/0EmeFodog0B...
# 3   https://api.spotify.com/v1/artists/1Xyo4u8uXC1...
# 4   https://api.spotify.com/v1/artists/66CXWjxzNUs...
# ..                                                ...
# ...

# %%
## Dropping duplicates in our artist_df dataframe
artist_df = artist_df.drop_duplicates(subset=['artist_id'])

# %%
#Song Dataframe
song_df = pd.DataFrame.from_dict(song_list)

# %%
song_df.head()
# Out:
#                   song_id            song_name  duration_ms  \
# 0  0yLdNVWF3Srea0uzk55zFn              Flowers       200454
# 1  0DWdj2oZMBFSzRsi2Cvfzf                  TQG       197933
# 2  7oDd86yk8itslrA9HRP2ki  Die For You - Remix       232857
# 3  1Qrg8KqiBpW07V7PNxwwwL            Kill Bill       153946
# 4  6AQbmUe0Qwf5PZnt4HmTXv   Boy's a liar Pt. 2       131013
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/0yLdNVWF3Srea0u...         100
# 1  https://open.spotify.com/track/0DWdj2oZMBFSzRs...          90
# 2  https://open.spotify.com/track/7oDd86yk8itslrA...          90
# 3  https://open.spotify.com/track/1Qrg8KqiBpW07V7...          92
# 4  https://open.spotify.com/track/6AQbmUe0Qwf5PZn...          93
#
#              song_added                album_id               artist_id
# 0  2023-03-03T10:15:38Z  7I0tjwFtxUwBC1vgyeMAax  5YGY8feqx7naU7z4HrwZM6
# ...

# %% [markdown]
# ### Getting table schema

# %%
dimalbum = pd.io.sql.get_schema(album_df.reset_index(), 'album_df')
print(''.join(dimalbum))
# Out:
# CREATE TABLE "album_df" (
# "index" INTEGER,
#   "album_id" TEXT,
#   "name" TEXT,
#   "release_date" TEXT,
#   "total_tracks" INTEGER,
#   "url" TEXT
# )

# %%
dimartist = pd.io.sql.get_schema(artist_df.reset_index(), 'artist_df')
print(''.join(dimartist))
# Out:
# CREATE TABLE "artist_df" (
# "index" INTEGER,
#   "artist_id" TEXT,
#   "artist_name" TEXT,
#   "external_url" TEXT
# )

# %%
dimsong = pd.io.sql.get_schema(song_df.reset_index(), 'song_df')
print(''.join(dimsong))
# Out:
# CREATE TABLE "song_df" (
# "index" INTEGER,
#   "song_id" TEXT,
#   "song_name" TEXT,
#   "duration_ms" INTEGER,
#   "url" TEXT,
#   "popularity" INTEGER,
#   "song_added" TEXT,
#   "album_id" TEXT,
#   "artist_id" TEXT
# )

# %% [markdown]
# ## Transform Data

# %%
## transforming release_date type to datetime
album_df['release_date'] = pd.to_datetime(album_df['release_date'])

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      48 non-null     object
#  1   name          48 non-null     object
#  2   release_date  48 non-null     datetime64[ns]
#  3   total_tracks  48 non-null     int64
#  4   url           48 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 2.2+ KB

# %%
song_df['song_added'] =  pd.to_datetime(song_df['song_added'])

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      50 non-null     object
#  1   song_name    50 non-null     object
#  2   duration_ms  50 non-null     int64
#  3   url          50 non-null     object
#  4   popularity   50 non-null     int64
#  5   song_added   50 non-null     datetime64[ns, UTC]
#  6   album_id     50 non-null     object
#  7   artist_id    50 non-null     object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 3.2+ KB
